# %% [markdown]
# # **Project Name : Music Band name generator.**
#
# 1) Ask in which city the user has born or grew up
# 2) Ask their pet name
# 3) Combine the two inputs and generate it as music band name

# %%
print("Welcome to Band name generator !!!!")
city = input("What's the name of the city you were born or grew up?? \n")
pet_name = input("What's your pet name? \n")
print("your band name could be "+city+" "+pet_name)
# Out:
# Welcome to Band name generator !!!!
# What's the name of the city you were born or grew up??
# Jagtial
# What's your pet name?
# Leo
# your band name could be Jagtial Leo
